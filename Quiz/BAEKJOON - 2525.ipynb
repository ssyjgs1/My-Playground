# %% [markdown]
# 문제 출처 : https://www.acmicpc.net/problem/2525
#
# KOI 전자에서는 건강에 좋고 맛있는 훈제오리구이 요리를 간편하게 만드는 인공지능 오븐을 개발하려고 한다. 인공지능 오븐을 사용하는 방법은 적당한 양의 오리 훈제 재료를 인공지능 오븐에 넣으면 된다. 그러면 인공지능 오븐은 오븐구이가 끝나는 시간을 분 단위로 자동적으로 계산한다.
#
# 또한, KOI 전자의 인공지능 오븐 앞면에는 사용자에게 훈제오리구이 요리가 끝나는 시각을 알려 주는 디지털 시계가 있다.
#
# 훈제오리구이를 시작하는 시각과 오븐구이를 하는 데 필요한 시간이 분단위로 주어졌을 때, 오븐구이가 끝나는 시각을 계산하는 프로그램을 작성하시오.
#
# 입력 : 첫째 줄에는 현재 시각이 나온다. 현재 시각은 시 A (0 ≤ A ≤ 23) 와 분 B (0 ≤ B ≤ 59)가 정수로 빈칸을 사이에 두고 순서대로 주어진다. 두 번째 줄에는 요리하는 데 필요한 시간 C (0 ≤ C ≤ 1,000)가 분 단위로 주어진다.
#
# 출력 : 첫째 줄에 종료되는 시각의 시와 분을 공백을 사이에 두고 출력한다. (단, 시는 0부터 23까지의 정수, 분은 0부터 59까지의 정수이다. 디지털 시계는 23시 59분에서 1분이 지나면 0시 0분이 된다.)

# %%
A, B = map(int, input().split()) # 시, 분
C = int(input()) # 돌릴 시간

# B + C가 60을 넘느냐(+포함) 안 넘느냐?
# A가 24를 넘느냐(+포함) 안 넘느냐?

A += C // 60 # 기존 주어진 시 + 돌리는 시간(분 단위의 몫) --> 끝나는 시
B += C % 60 # 기존 주어진 분 + 돌리는 시간(분 단위의 나머지) --> 끝나는 분

if(B >= 60): # 연산한 B가 60을 넘는다면?
    B -= 60 # B에서 60만큼 빼주고
    A += 1 # A에 1시간만큼을 더해준다 .

if(A >= 24): # 연산해서 나온 A가 24거나 넘는다면?
    A -= 24 # 24를 빼준다. 0이든 그 이상의 수가 찍힐 것
    
print(A, B) # 최종 연산된 시와 분을 차례로 표기해준다.

# %% [markdown]
# 이번 문제는 분명 조건을 걸어서 푼다는 것도 알겠고 주석에 표기했듯이 분끼리 합산한 결과가 60을 넘느냐 안 넘느냐, A가 24를 넘느냐 안 넘느냐를 고려해야 하는 문제였다.
#
# 문제는 이걸 명확히 몇 개의 조건으로 나뉘는지 파악을 못 했다.
#
# 이에 풀이를 한 번 찾아보고 풀 수 있었다.
